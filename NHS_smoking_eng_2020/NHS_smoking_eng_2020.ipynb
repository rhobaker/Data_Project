# %%
import pandas as pd
table1_1 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/NHS_smoking_eng_2020/Table S.1.1-Table 1.csv")
table1_1
# Out:
#        Year All admissions: Admissions All admissions: Attributable number  \
# 0   2009/10                  9,742,483                             461,700
# 1   2010/11                 10,012,763                             459,900
# 2   2011/12                 10,164,003                             459,700
# 3   2012/13                 10,281,507                             460,900
# 4   2013/14                 10,602,739                             454,700
# 5   2014/15                 11,011,882                             474,600
# 6   2015/16                 11,246,239                             474,300
# 7   2016/17                 11,486,913                             484,700
# 8   2017/18                 11,575,602                             489,300
# 9   2018/19                 12,064,747                             504,200
# 10  2019/20                 12,223,212                             506,100
#
#     All admissions: Attributable percentage  \
# ...

# %%
table1_2 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/NHS_smoking_eng_2020/Table S.1.2-Table 1.csv")
table1_2
# Out:
#                                                                         ICD-10 Diagnosis  \
# All admissions                                                            All admissions
# All cancers                                                                  All cancers
# All respiratory diseases                                        All respiratory diseases
# All circulatory diseases                                        All circulatory diseases
# All diseases of the digestive system                All diseases of the digestive system
# Cancers which can be caused by smoking                           Trachea, Lung, Bronchus
# Cancers which can be caused by smoking                           Upper Respiratory Sites
# Cancers which can be caused by smoking                                        Oesophagus
# Cancers which can be caused by smoking                                            Larynx
# ...

# %%
table1_3 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/NHS_smoking_eng_2020/Table S.1.3-Table 1.csv")
table1_3
# Out:
#                                      ICD-10 Diagnosis  \
# 0                                      All admissions
# 1                                         All cancers
# 2                            All respiratory diseases
# 3                            All circulatory diseases
# 4                All diseases of the digestive system
# 5              Cancers which can be caused by smoking
# 6              Cancers which can be caused by smoking
# 7              Cancers which can be caused by smoking
# 8              Cancers which can be caused by smoking
# 9              Cancers which can be caused by smoking
# 10             Cancers which can be caused by smoking
# 11             Cancers which can be caused by smoking
# 12             Cancers which can be caused by smoking
# 13             Cancers which can be caused by smoking
# 14             Cancers which can be caused by smoking
# 15             Cancers which can be caused by smoking
# ...

# %%
table1_4 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/NHS_smoking_eng_2020/Table S.1.4-Table 1.csv")
table1_4
# Out:
#     Year All deaths: Observed deaths All deaths: Attributable number3  \
# 0   2009                     448,230                           82,000
# 1   2010                     450,571                           80,300
# 2   2011                     442,759                           78,600
# 3   2012                     457,149                           78,700
# 4   2013                     463,986                           78,200
# 5   2014                     459,087                           77,800
# 6   2015                     485,625                           79,100
# 7   2016                     481,280                           77,900
# 8   2017                     489,455                           77,800
# 9   2018                     496,474                           77,000
# 10  2019                     487,111                           74,600
#
#     All deaths: Attributable percentage4  \
# 0                                     18
# ...

# %%
table1_5 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/NHS_smoking_eng_2020/Table S.1.5-Table 1.csv")
table1_5
# Out:
#                                      Diagnosis ICD-10  \
# 0                                          All deaths
# 1                                         All cancers
# 2                            All respiratory diseases
# 3                            All circulatory diseases
# 4                All diseases of the digestive system
# 5              Cancers which can be caused by smoking
# 6              Cancers which can be caused by smoking
# 7              Cancers which can be caused by smoking
# 8              Cancers which can be caused by smoking
# 9              Cancers which can be caused by smoking
# 10             Cancers which can be caused by smoking
# 11             Cancers which can be caused by smoking
# 12             Cancers which can be caused by smoking
# 13             Cancers which can be caused by smoking
# 14             Cancers which can be caused by smoking
# 15             Cancers which can be caused by smoking
# ...

# %%
table1_6 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/NHS_smoking_eng_2020/Table S.1.6-Table 1.csv")
table1_6
# Out:
#                                      Diagnosis ICD-10  \
# 0                                          All deaths
# 1                                         All cancers
# 2                            All respiratory diseases
# 3                            All circulatory diseases
# 4                All diseases of the digestive system
# 5              Cancers which can be caused by smoking
# 6              Cancers which can be caused by smoking
# 7              Cancers which can be caused by smoking
# 8              Cancers which can be caused by smoking
# 9              Cancers which can be caused by smoking
# 10             Cancers which can be caused by smoking
# 11             Cancers which can be caused by smoking
# 12             Cancers which can be caused by smoking
# 13             Cancers which can be caused by smoking
# 14             Cancers which can be caused by smoking
# 15             Cancers which can be caused by smoking
# ...

# %%
table2_1 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/NHS_smoking_eng_2020/Table S.2.1-Table 1.csv")
table2_1
# Out:
#                                                    All \r\npharmacotherapies2  \
# 2009/10 Number of prescription items3 (000s)                            2,483
# 2010/11 Number of prescription items3 (000s)                            2,564
# 2011/12 Number of prescription items3 (000s)                            2,532
# 2012/13 Number of prescription items3 (000s)                            2,203
# 2013/14 Number of prescription items3 (000s)                            1,778
# 2014/15 Number of prescription items3 (000s)                            1,348
# 2015/16 Number of prescription items3 (000s)                            1,154
# 2016/17 Number of prescription items3 (000s)                              975
# 2017/18 Number of prescription items3 (000s)                              858
# 2018/19 Number of prescription items3 (000s)                              740
# 2019/20 Number of prescription items3 (000s)                              710
# ...

# %%
table2_2 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/NHS_smoking_eng_2020/Table S.2.2-Table 1.csv")
table2_2
# Out:
#     ONS / CCG code  Unnamed: 1 Unnamed: 2  \
# 0        E38000001         NaN        02N
# 1        E38000006         NaN        02P
# 2        E38000008         NaN        02Q
# 3        E38000018         NaN        02W
# 4        E38000019         NaN        02R
# ..             ...         ...        ...
# 186      E38000009         NaN        11E
# 187      E38000062         NaN        11M
# 188      E38000181         NaN        12D
# 189      E38000206         NaN        99N
# 190      E38000222         NaN        15C
#
#                  Commissioning region, region and CCG1  \
# 0              NHS Airedale, Wharfedale and Craven CCG
# 1                                     NHS Barnsley CCG
# 2                                    NHS Bassetlaw CCG
# 3                                NHS Bradford City CCG
# 4                          NHS Bradford Districts CCG2
# ..                                                 ...
# 186               NHS Bath and North East Somerset CCG
# ...

# %%
table3_1 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/NHS_smoking_eng_2020/Table S.3.1-Table 1.csv")
table3_1
# Out:
#     Year  Tobacco \r\nprice\r\nindex (TPI)  \
# 0   1987                             100.1
# 1   1988                             103.4
# 2   1989                             106.4
# 3   1990                             113.6
# 4   1991                             129.9
# 5   1992                             144.2
# 6   1993                             156.4
# 7   1994                             168.2
# 8   1995                             179.5
# 9   1996                             191.5
# 10  1997                             205.6
# 11  1998                             223.3
# 12  1999                             248.9
# 13  2000                             270.4
# 14  2001                             285.1
# 15  2002                             293.7
# 16  2003                             304.1
# 17  2004                             315.0
# 18  2005                             328.7
# 19  2006                             343.4
# 20  2007                             361.6
# ...

# %%
table3_2 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/NHS_smoking_eng_2020/Table S.3.2-Table 1.csv")
table3_2
# Out:
#     Year Household \r\nexpenditure\r\non tobacco  \
# 0   1985                                   7,000
# 1   1986                                   7,463
# 2   1987                                   7,631
# 3   1988                                   7,890
# 4   1989                                   8,112
# 5   1990                                   8,576
# 6   1991                                   9,556
# 7   1992                                  10,169
# 8   1993                                  10,631
# 9   1994                                  10,787
# 10  1995                                  11,349
# 11  1996                                  12,068
# 12  1997                                  12,485
# 13  1998                                  13,267
# 14  1999                                  14,084
# 15  2000                                  14,149
# 16  2001                                  14,208
# 17  2002                                  14,233
# ...

# %%
tableB_1 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/NHS_smoking_eng_2020/Table S.B.1-Table 1.csv")
tableB_1
# Out:
#   Unnamed: 0  Men: current smokers  Men: ex smokers  Women: current smokers  \
# 0  35 & Over                 0.140            0.342                   0.109
# 1  45 & Over                 0.128            0.371                   0.104
# 2      35-54                 0.177            0.258                   0.133
# 3      55-64                 0.141            0.321                   0.127
# 4      65-74                 0.102            0.447                   0.082
# 5  75 & Over                 0.059            0.529                   0.047
# 6      35-64                 0.166            0.278                   0.131
# 7  65 & Over                 0.084            0.482                   0.066
#
#    Women: ex smokers
# 0              0.275
# 1              0.291
# 2              0.231
# 3              0.272
# 4              0.342
# 5              0.323
# 6              0.245
# 7              0.333

# %%
tableB_2 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/NHS_smoking_eng_2020/Table S.B.2-Table 1.csv")
tableB_2
# Out:
#                        Disease category  \
# 0               Trachea, Lung, Bronchus
# 1               Upper respiratory sites
# 2                            Oesophagus
# 3                                Larynx
# 4                              Cervical
# 5                               Bladder
# 6              Kidney and Renal Pelvis2
# 7                               Stomach
# 8                              Pancreas
# 9                     Unspecified site2
# 10                   Myeloid leukaemia2
# 11     Chronic obstructive lung disease
# 12           Chronic Airway Obstruction
# 13                Pneumonia, Influenza2
# 14                Pneumonia, Influenza2
# 15                  Other Heart Disease
# 16             Ischaemic heart disease2
# 17             Ischaemic heart disease2
# 18             Ischaemic heart disease2
# 19             Ischaemic heart disease2
# 20               Other arterial disease
# 21             Cerebrovascular disease2
# ...
