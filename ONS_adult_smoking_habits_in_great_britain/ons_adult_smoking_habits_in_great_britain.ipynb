# %%
import pandas as pd
table1a = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub repository/onsadultsmokinghabitsingreatbritaindataonly/Table_1a-Table 1.csv")
table1a
# Out:
#    Weight \n[note 4] Year \n[note 5]  Men \naged \n16 to 24  \
# 0           Weighted  2022 [note 11]                    9.9
# 1           Weighted  2021 [note 11]                   13.5
# 2           Weighted  2020 [note 10]                   15.9
# 3           Weighted            2019                   20.7
# 4           Weighted            2018                   28.0
# 5           Weighted            2017                   23.9
# 6           Weighted            2016                   17.2
# 7           Weighted            2015                   24.1
# 8           Weighted            2014                   25.2
# 9           Weighted            2013                   26.4
# 10          Weighted            2012                   21.9
# 11          Weighted   2011 [note 7]                   24.0
# 12          Weighted   2010 [note 7]                   22.2
# 13          Weighted   2009 [note 7]                   23.5
# 14          Weighted   2008 [note 7]                   23.7
# ...

# %%
table1b = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub repository/onsadultsmokinghabitsingreatbritaindataonly/Table_1b-Table 1.csv")
table1b
# Out:
#                       Statistic  Year Men \naged \n16 to 24  \
# 0  Weighted base (in thousands)  2022                 3,407
# 1             Unweighted sample  2022                 1,651
#
#   Men \naged \n25 to 34 Men \naged \n35 to 49 Men \naged \n50 to 59  \
# 0                 4,337                 5,958                 4,156
# 1                 2,282                 4,105                 3,974
#
#   Men \naged \n60 and over Men \naged \n16 and over Women \naged \n16 to 24  \
# 0                    7,773                   25,630                   3,259
# 1                   16,962                    1,651                   2,110
#
#   Women \naged \n25 to 34  ... Women \naged \n50 to 59  \
# 0                   4,269  ...                   4,208
# 1                   3,253  ...                   4,780
#
#   Women \naged \n60 and over Women \naged \n16 and over  \
# 0                      8,809                     26,672
# 1                     19,864                      2,282
#
# ...

# %%
table2a = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub repository/onsadultsmokinghabitsingreatbritaindataonly/Table_2a-Table 1.csv")
table2a
# Out:
#    Weight \n[note 4] Year \n[note 5]\n[note 9]  Men \naged \n16 to 24  \
# 0           Weighted            2022 [note 11]                   86.5
# 1           Weighted            2021 [note 11]                   82.9
# 2           Weighted            2020 [note 10]                   80.1
# 3           Weighted                      2019                   76.1
# 4           Weighted                      2018                   69.5
# 5           Weighted                      2017                   68.8
# 6           Weighted                      2016                   77.6
# 7           Weighted                      2015                   68.2
# 8           Weighted                      2014                   69.7
# 9           Weighted                      2013                   70.6
# 10          Weighted                      2012                   74.8
# 11          Weighted             2011 [note 7]                   70.1
# ...

# %%
table2b = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub repository/onsadultsmokinghabitsingreatbritaindataonly/Table_2b-Table 1.csv")
table2b
# Out:
#                       Statistic  Year Men \naged \n16 to 24  \
# 0  Weighted base (in thousands)  2022                 3,407
# 1             Unweighted sample  2022                 1,651
#
#   Men \naged \n25 to 34 Men \naged \n35 to 49 Men \naged \n50 to 59  \
# 0                 4,337                 5,958                 4,156
# 1                 2,282                 4,105                 3,974
#
#   Men \naged \n60 and over Men \naged \n16 and over Women \naged \n16 to 24  \
# 0                    7,773                   25,630                   3,259
# 1                   16,962                   28,974                   2,110
#
#   Women \naged \n25 to 34  ... Women \naged \n50 to 59  \
# 0                   4,269  ...                   4,208
# 1                   3,253  ...                   4,780
#
#   Women \naged \n60 and over Women \naged \n16 and over  \
# 0                      8,809                     26,672
# 1                     19,864                     35,353
#
# ...

# %%
table3a = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub repository/onsadultsmokinghabitsingreatbritaindataonly/Table_3a-Table 1.csv")
table3a
# Out:
#    Weight \n[note 4] Year \n[note 5] Men \naged \n16 to 24  \
# 0           Weighted  2022 [note 11]                  26.7
# 1           Weighted  2021 [note 11]                  21.3
# 2           Weighted  2020 [note 10]                  20.5
# 3           Weighted   2019 [note 8]              13.3 [u]
# 4           Weighted            2018                   8.4
# 5           Weighted            2017                  23.3
# 6           Weighted            2016                  23.6
# 7           Weighted            2015                  24.0
# 8           Weighted            2014                  16.7
# 9           Weighted            2013                  10.1
# 10          Weighted            2012                  13.3
# 11          Weighted   2011 [note 7]                  19.9
# 12          Weighted   2010 [note 7]                  20.3
# 13          Weighted   2009 [note 7]                  15.1
# 14          Weighted   2008 [note 7]                  22.2
# ...

# %%
table3b = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub repository/onsadultsmokinghabitsingreatbritaindataonly/Table_3b-Table 1.csv")
table3b
# Out:
#                       Statistic  Year  Men \naged \n16 to 24  \
# 0  Weighted base (in thousands)  2022                    462
# 1             Unweighted sample  2022                    216
#
#   Men \naged \n25 to 34 Men \naged \n35 to 49 Men \naged \n50 to 59  \
# 0                 1,225                 2,431                 2,007
# 1                   606                 1,561                 1,751
#
#   Men \naged \n60 and over Men \naged \n16 and over  Women \naged \n16 to 24  \
# 0                    4,165                   10,290                      474
# 1                    8,483                   12,617                      306
#
#   Women \naged \n25 to 34  ... Women \naged \n50 to 59  \
# 0                   1,164  ...                   1,754
# 1                     826  ...                   1,864
#
#   Women \naged \n60 and over Women \naged \n16 and over  \
# 0                      3,464                      8,871
# ...

# %%
table4 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub repository/onsadultsmokinghabitsingreatbritaindataonly/Table_4-Table 1.csv")
table4
# Out:
#                          Statistic  \
# 0  Proportion of cigarette smokers
# 1  Proportion of cigarette smokers
# 2  Proportion of cigarette smokers
# 3  Proportion of cigarette smokers
# 4  Proportion of cigarette smokers
# 5  Proportion of cigarette smokers
# 6     Weighted base (in thousands)
# 7                Unweighted sample
#
#   Time to first cigarette of the day after waking [note 12] 2022 [note 11]  \
# 0                                Less than 5 minutes                  13.3
# 1                                    5 to 14 minutes                  20.3
# 2                                   15 to 29 minutes                  17.3
# 3                    30 minutes but less than 1 hour                  11.8
# 4                       1 hour but less than 2 hours                  11.2
# 5                                    2 hours or more                  26.1
# 6                                  Cigarette smokers                 1,120
# ...

# %%
table5 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub repository/onsadultsmokinghabitsingreatbritaindataonly/Table_5-Table 1.csv")
table5
# Out:
#                          Statistic         Intention to quit [note 13]   2022  \
# 0  Proportion of cigarette smokers               Not intending to quit   16.3
# 1  Proportion of cigarette smokers    Wants to quit, but no time frame   23.4
# 2  Proportion of cigarette smokers  Wants to quit in the next 3 months   22.0
# 3  Proportion of cigarette smokers            Does not know either way   38.3
# 4     Weighted base (in thousands)                   Cigarette smokers  1,132
# 5                Unweighted sample                   Cigarette smokers    206
#
#   2021 [note 11] 2020 [note10]   2019   2018   2017   2016   2015  Unnamed: 10
# 0           16.9          12.3   19.4   21.8   33.3   35.6   35.8          NaN
# 1           33.6          35.5   31.6   39.8   49.4   48.0   48.5          NaN
# 2           21.7          23.0   21.1   18.6   11.4   11.3   12.3          NaN
# 3           27.8          29.1   27.8   19.8    5.9    5.1    3.4          NaN
# ...

# %%
table6 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub repository/onsadultsmokinghabitsingreatbritaindataonly/Table_6-Table 1.csv")
table6
# Out:
#                           Statistic            Year  \
# 0   Proportion of cigarette smokers  2022 [note 11]
# 1   Proportion of cigarette smokers  2022 [note 11]
# 2   Proportion of cigarette smokers  2022 [note 11]
# 3   Proportion of cigarette smokers  2021 [note 11]
# 4   Proportion of cigarette smokers  2021 [note 11]
# 5   Proportion of cigarette smokers  2021 [note 11]
# 6   Proportion of cigarette smokers  2020 [note 10]
# 7   Proportion of cigarette smokers  2020 [note 10]
# 8   Proportion of cigarette smokers  2020 [note 10]
# 9   Proportion of cigarette smokers            2019
# 10  Proportion of cigarette smokers            2019
# 11  Proportion of cigarette smokers            2019
# 12  Proportion of cigarette smokers            2018
# 13  Proportion of cigarette smokers            2018
# 14  Proportion of cigarette smokers            2018
# 15  Proportion of cigarette smokers            2017
# 16  Proportion of cigarette smokers            2017
# ...

# %%
table7 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub repository/onsadultsmokinghabitsingreatbritaindataonly/Table_7-Table 1.csv")
table7
# Out:
#     Table                         Group  \
# 0       1                Men aged 16-24
# 1       1                Men aged 25-34
# 2       1                Men aged 35-49
# 3       1                Men aged 50-59
# 4       1          Men aged 60 and over
# ..    ...                           ...
# 71      6  All persons aged 16 and over
# 72      6  All persons aged 16 and over
# 73      6  All persons aged 16 and over
# 74      6  All persons aged 16 and over
# 75      6  All persons aged 16 and over
#
#                                             Statistic  2022 \nEstimate  \
# 0       Proportion of population who smoke cigarettes              9.9
# 1       Proportion of population who smoke cigarettes             14.4
# 2       Proportion of population who smoke cigarettes             13.7
# 3       Proportion of population who smoke cigarettes             17.3
# 4       Proportion of population who smoke cigarettes              9.0
# ...
