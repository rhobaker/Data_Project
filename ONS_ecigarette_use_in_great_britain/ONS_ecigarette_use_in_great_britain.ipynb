# %%
import pandas as pd
table1a = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/ONS_ecigarette_use_in_great_britain/Table_1a-Table 1.csv")
table1a
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Table 1
# ...

# %%
table1b = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/ONS_ecigarette_use_in_great_britain/Table_1b-Table 1.csv")
table1b
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Table 1
# ...

# %%
table1c = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/ONS_ecigarette_use_in_great_britain/Table_1c-Table 1.csv")
table1c
# Out:
#     Year  \
# 0   2017
# 1   2017
# 2   2017
# 3   2017
# 4   2017
# 5   2017
# 6   2016
# 7   2016
# 8   2016
# 9   2016
# 10  2016
# 11  2016
# 12  2015
# 13  2015
# 14  2015
# 15  2015
# 16  2015
# 17  2015
# 18  2014
# 19  2014
# 20  2014
# 21  2014
# 22  2014
# 23  2014
#
#    Proportion of population aged 16 years and over by e-cigarette use [note 1]  \
# 0              Current e-cigarette user, or vaper (%)
# 1                                        Ex vaper (%)
# 2       Tried vaping, but didn't continue to vape (%)
# 3                                     Never vaped (%)
# 4                        Weighted base (in thousands)
# 5                                   Unweighted sample
# 6              Current e-cigarette user, or vaper (%)
# 7                                        Ex vaper (%)
# 8       Tried vaping, but didn't continue to vape (%)
# 9                                     Never vaped (%)
# 10                       Weighted base (in thousands)
# ...

# %%
table2a = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/ONS_ecigarette_use_in_great_britain/Table_2a-Table 1.csv")
table2a
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                        Table 1
# Year Proportion of population aged 16 years and over... Men \r\nCigarette smoker \r\n[note 2] Men \r\nEx-smokers \r\n[note 3] Men \r\nNever smoked \r\n[note 4] Women \r\nCigarette smoker \r\n[note 2] Women \r\nEx-smokers \r\n[note 3] Women \r\nNever smoked \r\n[note 4] All persons \r\nCigarette smoker \r\n[note 2] All persons \r\nEx-smokers \r\n[note 3]  All persons \r\nNever smoked \r\n[note 4]
# ...

# %%
table2b = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/ONS_ecigarette_use_in_great_britain/Table_2b-Table 1.csv")
table2b
# Out:
#                                                                                                                                                                                                                                                                                                                                                                    Table 1
# Year Proportion of population aged 16 years and over... Men \nCigarette smoker \n[note 2] Men \nEx-smokers \n[note 3] Men \nNever smoked \n[note 4] Women \nCigarette smoker \n[note 2] Women \nEx-smokers \n[note 3] Women \nNever smoked \n[note 4] All persons \nCigarette smoker \n[note 2] All persons \nEx-smokers \n[note 3]  All persons \nNever smoked \n[note 4]
# ...

# %%
table2c = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/ONS_ecigarette_use_in_great_britain/Table_2c-Table 1.csv") 
table2c
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                        Table 1
# Year Proportion of population aged 16 years and over... Men \r\nCigarette smoker \r\n[note 2] Men \r\nEx-smokers \r\n[note 3] Men \r\nNever smoked \r\n[note 4] Women \r\nCigarette smoker \r\n[note 2] Women \r\nEx-smokers \r\n[note 3] Women \r\nNever smoked \r\n[note 4] All persons \r\nCigarette smoker \r\n[note 2] All persons \r\nEx-smokers \r\n[note 3]  All persons \r\nNever smoked \r\n[note 4]
# ...

# %%
table3_a = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/ONS_ecigarette_use_in_great_britain/Table_3_a-Table 1.csv")
table3_a
# Out:
#      Table                          Group  \
# 0        1                 Men aged 16-24
# 1        1                 Men aged 25-34
# 2        1                 Men aged 35-49
# 3        1                 Men aged 50-59
# 4        1           Men aged 60 and over
# ..     ...                            ...
# 103      2        Women aged 16 and over
# 104      2        Women aged 16 and over
# 105      2   All persons aged 16 and over
# 106      2  All persons aged 16 and over
# 107      2  All persons aged 16 and over
#
#                                              Statistic  2022 Estimate  \
# 0    Proportion of population who are daily e-cigar...            3.6
# 1    Proportion of population who are daily e-cigar...            7.4
# 2    Proportion of population who are daily e-cigar...            8.2
# 3    Proportion of population who are daily e-cigar...            7.4
# 4    Proportion of population who are daily e-cigar...            3.7
# ...

# %%
table3_b = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/ONS_ecigarette_use_in_great_britain/Table_3_b-Table 1.csv")
table3_b
# Out:
#      Table                          Group  \
# 0        1                 Men aged 16-24
# 1        1                 Men aged 25-34
# 2        1                 Men aged 35-49
# 3        1                 Men aged 50-59
# 4        1           Men aged 60 and over
# ..     ...                            ...
# 103      2        Women aged 16 and over
# 104      2        Women aged 16 and over
# 105      2   All persons aged 16 and over
# 106      2  All persons aged 16 and over
# 107      2  All persons aged 16 and over
#
#                                              Statistic  2019 \nEstimate  \
# 0    Proportion of population who are current e-cig...              3.2
# 1    Proportion of population who are current e-cig...              7.7
# 2    Proportion of population who are current e-cig...              9.3
# 3    Proportion of population who are current e-cig...              6.6
# 4    Proportion of population who are current e-cig...              3.8
# ...
