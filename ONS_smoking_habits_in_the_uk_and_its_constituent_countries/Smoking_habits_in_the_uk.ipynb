# %%
import pandas as pd
table_1 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/Smoking Habits/Table_1.csv")
table_1
# Out:
#          Sex Country code         Country Age group  \
# 0    Persons    E92000001         England     18-24
# 1    Persons    E92000001         England     25-34
# 2    Persons    E92000001         England     35-44
# 3    Persons    E92000001         England     45-54
# 4    Persons    E92000001         England     55-64
# ..       ...          ...             ...       ...
# 100    Women    K02000001  United Kingdom     35-44
# 101    Women    K02000001  United Kingdom     45-54
# 102    Women    K02000001  United Kingdom     55-64
# 103    Women    K02000001  United Kingdom       65+
# 104    Women    K02000001  United Kingdom   All 18+
#
#      2022 \nCurrent smokers \n%  2022 \nCurrent smokers \nLCL  \
# 0                          11.6                          10.5
# 1                          16.3                          15.4
# 2                          14.4                          13.6
# 3                          13.9                          13.2
# ...

# %%
table_2 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/Smoking Habits/Table_2.csv")
table_2
# Out:
#          Sex Region code Region of England Age group  \
# 0    Persons   E12000001        North East     18-24
# 1    Persons   E12000001        North East     25-34
# 2    Persons   E12000001        North East     35-44
# 3    Persons   E12000001        North East     45-54
# 4    Persons   E12000001        North East     55-64
# ..       ...         ...               ...       ...
# 184    Women   E12000009        South West     35-44
# 185    Women   E12000009        South West     45-54
# 186    Women   E12000009        South West     55-64
# 187    Women   E12000009        South West       65+
# 188    Women   E12000009        South West   All 18+
#
#      2022 \nCurrent smokers \n%  2022 \nCurrent smokers \nLCL  \
# 0                          12.8                           8.9
# 1                          16.8                          13.8
# 2                          13.9                          11.4
# 3                          13.6                          11.2
# ...

# %%
table_3 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/Smoking Habits/Table_3.csv")
table_3
# Out:
#         Sex County code \n[note 7] County name \n[note 7]  \
# 0   Persons              E10000002        Buckinghamshire
# 1   Persons              E10000003         Cambridgeshire
# 2   Persons              E10000006                Cumbria
# 3   Persons              E10000007             Derbyshire
# 4   Persons              E10000008                  Devon
# ..      ...                    ...                    ...
# 73    Women              E10000029                Suffolk
# 74    Women              E10000030                 Surrey
# 75    Women              E10000031           Warwickshire
# 76    Women              E10000032            West Sussex
# 77    Women              E10000034         Worcestershire
#
#    2022 \nCurrent smokers \n% 2022 \nCurrent smokers \nLCL  \
# 0                         [x]                          [x]
# 1                        11.3                          8.7
# 2                        13.1                         10.4
# ...

# %%
table_4 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/Smoking Habits/Table_4.csv")
table_4
# Out:
#           Sex Region Code       Region Name  \
# 0     Persons   E12000001        North East
# 1     Persons   E12000001        North East
# 2     Persons   E12000001        North East
# 3     Persons   E12000001        North East
# 4     Persons   E12000001        North East
# ...       ...         ...               ...
# 1150    Women   N92000002  Northern Ireland
# 1151    Women   N92000002  Northern Ireland
# 1152    Women   N92000002  Northern Ireland
# 1153    Women   N92000002  Northern Ireland
# 1154    Women   N92000002  Northern Ireland
#
#      Local Authority Code \n[note 6]\n[note 20] [note 21]  \
# 0                                             E06000001
# 1                                             E06000002
# 2                                             E06000003
# 3                                             E06000004
# 4                                             E06000005
# ...                                                 ...
# ...

# %%
table_5a = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/Smoking Habits/Table_5a.csv")
table_5a
# Out:
#    Code \n[note 8]   Name of English Integrated Care Board \n[note 8]  \
# 0        E54000008  NHS Cheshire and Merseyside Integrated Care Board
# 1        E54000010  NHS Staffordshire and Stoke-on-Trent Integrate...
# 2        E54000011  NHS Shropshire, Telford and Wrekin Integrated ...
# 3        E54000013             NHS Lincolnshire Integrated Care Board
# 4        E54000015  NHS Leicester, Leicestershire and Rutland Inte...
# 5        E54000018  NHS Coventry and Warwickshire Integrated Care ...
# 6        E54000019  NHS Herefordshire and Worcestershire Integrate...
# 7        E54000022      NHS Norfolk and Waveney Integrated Care Board
# 8        E54000023  NHS Suffolk and North East Essex Integrated Ca...
# 9        E54000024  NHS Bedfordshire, Luton and Milton Keynes Inte...
# 10       E54000025  NHS Hertfordshire and West Essex Integrated Ca...
# 11       E54000026      NHS Mid and South Essex Integrated Care Board
# ...

# %%
table_5b = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/Smoking Habits/Table_5b.csv")
table_5b
# Out:
#     Code \n[note 9]  \
# 0         E38000006
# 1         E38000007
# 2         E38000008
# 3         E38000014
# 4         E38000015
# ..              ...
# 108       W11000025
# 109       W11000028
# 110       W11000029
# 111       W11000030
# 112       W11000031
#
#     Name of English Clinical Commissioning Groups or Welsh Local Health Boards \n[note 9]  \
# 0                                     NHS Barnsley CCG
# 1                       NHS Basildon and Brentwood CCG
# 2                                    NHS Bassetlaw CCG
# 3                        NHS Blackburn with Darwen CCG
# 4                                    NHS Blackpool CCG
# ..                                                 ...
# 108                  Hywel Dda University Health Board
# 109              Aneurin Bevan University Health Board
# 110           Cardiff and Vale University Health Board
# 111          Cwm Taf Morgannwg University Health Board
# 112                Swansea Bay University Health Board
#
# ...

# %%
table_6 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/Smoking Habits/Table_6.csv")
table_6
# Out:
#    Country code           Country Economic activity group \n[note 10]  \
# 0     E92000001           England                       In Employment
# 1     E92000001           England                          Unemployed
# 2     E92000001           England                            Inactive
# 3     W92000004             Wales                       In Employment
# 4     W92000004             Wales                          Unemployed
# 5     W92000004             Wales                            Inactive
# 6     S92000003          Scotland                       In Employment
# 7     S92000003          Scotland                          Unemployed
# 8     S92000003          Scotland                            Inactive
# 9     N92000002  Northern Ireland                       In Employment
# 10    N92000002  Northern Ireland                          Unemployed
# 11    N92000002  Northern Ireland                            Inactive
# ...

# %%
table_7 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/Smoking Habits/Table_7.csv")
table_7
# Out:
#    Country code           Country  \
# 0     E92000001           England
# 1     E92000001           England
# 2     E92000001           England
# 3     E92000001           England
# 4     W92000004             Wales
# 5     W92000004             Wales
# 6     W92000004             Wales
# 7     W92000004             Wales
# 8     S92000003          Scotland
# 9     S92000003          Scotland
# 10    S92000003          Scotland
# 11    S92000003          Scotland
# 12    N92000002  Northern Ireland
# 13    N92000002  Northern Ireland
# 14    N92000002  Northern Ireland
# 15    N92000002  Northern Ireland
# 16    K02000001    United Kingdom
# 17    K02000001    United Kingdom
# 18    K02000001    United Kingdom
# 19    K02000001    United Kingdom
#
#                  Socio-economic group \n[note 11]  2022 \nCurrent smokers \n%  \
# 0         Managerial and professional occupations                         8.3
# ...

# %%
table_8 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/Smoking Habits/Table_8.csv")
table_8
# Out:
#    Country code           Country             Relationship status  \
# 0     E92000001           England    Married or civil partnership
# 1     E92000001           England                      Cohabiting
# 2     E92000001           England                          Single
# 3     E92000001           England  Widowed, divorced or separated
# 4     W92000004             Wales    Married or civil partnership
# 5     W92000004             Wales                      Cohabiting
# 6     W92000004             Wales                          Single
# 7     W92000004             Wales  Widowed, divorced or separated
# 8     S92000003          Scotland    Married or civil partnership
# 9     S92000003          Scotland                      Cohabiting
# 10    S92000003          Scotland                          Single
# 11    S92000003          Scotland  Widowed, divorced or separated
# 12    N92000002  Northern Ireland    Married or civil partnership
# ...

# %%
table_9 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/Smoking Habits/Table_9.csv")
table_9
# Out:
#    Country code           Country      Highest level of education  \
# 0     E92000001           England            Degree or equivalent
# 1     E92000001           England                Higher education
# 2     E92000001           England       GCE A level or equivalent
# 3     E92000001           England  GCSE grades A*-C or equivalent
# 4     E92000001           England             Other qualification
# 5     E92000001           England               No qualifications
# 6     W92000004             Wales            Degree or equivalent
# 7     W92000004             Wales                Higher education
# 8     W92000004             Wales       GCE A level or equivalent
# 9     W92000004             Wales  GCSE grades A*-C or equivalent
# 10    W92000004             Wales             Other qualification
# 11    W92000004             Wales               No qualifications
# 12    S92000003          Scotland            Degree or equivalent
# ...

# %%
table_10 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/Smoking Habits/Table_10.csv")
table_10
# Out:
#         Sex Country code         Country Ethnicity \n[note 14]  \
# 0   Persons    E92000001         England                 White
# 1   Persons    E92000001         England                 Mixed
# 2   Persons    E92000001         England                 Asian
# 3   Persons    E92000001         England               Chinese
# 4   Persons    E92000001         England                 Black
# 5   Persons    E92000001         England                 Other
# 6   Persons    K02000001  United Kingdom                 White
# 7   Persons    K02000001  United Kingdom                 Mixed
# 8   Persons    K02000001  United Kingdom                 Asian
# 9   Persons    K02000001  United Kingdom               Chinese
# 10  Persons    K02000001  United Kingdom                 Black
# 11  Persons    K02000001  United Kingdom                 Other
# 12      Men    E92000001         England                 White
# 13      Men    E92000001         England                 Mixed
# ...

# %%
table_11 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/Smoking Habits/Table_11.csv")
table_11
# Out:
#    Country code         Country      Country of birth \n[note 15]  \
# 0     E92000001         England                             India
# 1     E92000001         England               Republic of Ireland
# 2     E92000001         England                          Pakistan
# 3     E92000001         England                            Poland
# 4     E92000001         England                           England
# 5     E92000001         England                  Northern Ireland
# 6     E92000001         England                          Scotland
# 7     E92000001         England                             Wales
# 8     E92000001         England  UK (but do not know the country)
# 9     E92000001         England                             Other
# 10    K02000001  United Kingdom                             India
# 11    K02000001  United Kingdom               Republic of Ireland
# 12    K02000001  United Kingdom                          Pakistan
# ...

# %%
table_12 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/Smoking Habits/Table_12.csv")
table_12
# Out:
#    Country code  Country      Sex Religion \n[note 16]  \
# 0     E92000001  England  Persons          No religion
# 1     E92000001  England  Persons            Christian
# 2     E92000001  England  Persons             Buddhist
# 3     E92000001  England  Persons                Hindu
# 4     E92000001  England  Persons               Jewish
# 5     E92000001  England  Persons               Muslim
# 6     E92000001  England  Persons                 Sikh
# 7     E92000001  England  Persons       Other religion
# 8     E92000001  England      Men          No religion
# 9     E92000001  England      Men            Christian
# 10    E92000001  England      Men             Buddhist
# 11    E92000001  England      Men                Hindu
# 12    E92000001  England      Men               Jewish
# 13    E92000001  England      Men               Muslim
# 14    E92000001  England      Men                 Sikh
# 15    E92000001  England      Men       Other religion
# ...

# %%
table_13 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/Smoking Habits/Table_13.csv")
table_13
# Out:
#   Country code         Country                             Tenure \n[note 17]  \
# 0    E92000001         England                                  Owns outright
# 1    E92000001         England                             Owns with mortgage
# 2    E92000001         England  Rents: local authority or housing association
# 3    E92000001         England                               Rents: privately
# 4    K02000001  United Kingdom                                  Owns outright
# 5    K02000001  United Kingdom                             Owns with mortgage
# 6    K02000001  United Kingdom  Rents: local authority or housing association
# 7    K02000001  United Kingdom                               Rents: privately
#
#    2022\nCurrent smokers \n%  2022 \nCurrent smokers \nLCL  \
# 0                        7.3                           7.0
# 1                        8.9                           8.4
# 2                       26.0                          25.0
# ...

# %%
table_14 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/Smoking Habits/Table_14.csv")
table_14
# Out:
#         Sex Country code         Country Sexual orientation \n[note 18]  \
# 0   Persons    E92000001         England       Heterosexual or straight
# 1   Persons    E92000002         England                 Gay or lesbian
# 2   Persons    E92000003         England                       Bisexual
# 3   Persons    E92000001         England                          Other
# 4   Persons    K02000001  United Kingdom       Heterosexual or straight
# 5   Persons    K02000001  United Kingdom                 Gay or lesbian
# 6   Persons    K02000001  United Kingdom                       Bisexual
# 7   Persons    K02000001  United Kingdom                          Other
# 8       Men    E92000001         England       Heterosexual or straight
# 9       Men    E92000002         England                 Gay or lesbian
# 10      Men    E92000003         England                       Bisexual
# 11      Men    E92000001         England                          Other
# ...

# %%
table_15 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/Smoking Habits/Table_15.csv")
table_15
# Out:
#    Country code           Country  Smoking Status  \
# 0     E92000001           England  Current smoker
# 1     E92000001           England       Ex-smoker
# 2     E92000001           England    Never smoked
# 3     W92000004             Wales  Current smoker
# 4     W92000004             Wales       Ex-smoker
# 5     W92000004             Wales    Never smoked
# 6     S92000003          Scotland  Current smoker
# 7     S92000003          Scotland       Ex-smoker
# 8     S92000003          Scotland    Never smoked
# 9     N92000002  Northern Ireland  Current smoker
# 10    N92000002  Northern Ireland       Ex-smoker
# 11    N92000002  Northern Ireland    Never smoked
# 12    K02000001   United Kingdom   Current smoker
# 13    K02000001   United Kingdom        Ex-smoker
# 14    K02000001   United Kingdom     Never smoked
#
#     2022 \nVery good health \n%  2022 \nVery good health \nLCI  \
# 0                          21.7                           20.6
# ...

# %%
table_16 = pd.read_csv("/Users/rhonabaker/CFG/GROUP PROJECT/GitHub/GitHub repository/Smoking Habits/Table_16.csv")
table_16
# Out:
#    Country code           Country Respondent type \n[note 19]  \
# 0     E92000001           England           Personal response
# 1     E92000001           England              Other response
# 2     E92000001           England               All responses
# 3     W92000004             Wales           Personal response
# 4     W92000004             Wales              Other response
# 5     W92000004             Wales               All responses
# 6     S92000003          Scotland           Personal response
# 7     S92000003          Scotland              Other response
# 8     S92000003          Scotland               All responses
# 9     N92000002  Northern Ireland           Personal response
# 10    N92000002  Northern Ireland              Other response
# 11    N92000002  Northern Ireland               All responses
# 12    K02000001    United Kingdom           Personal response
# 13    K02000001    United Kingdom              Other response
# ...
